# %%
LoadPackage("num");
# Out:
# #I  Please load package NormalizInterface or 4ti2Interface
# #I  to have extended functionalities.
# #I  Please load package SingularInterface or singular (not both)
# #I  or GradedModules to have extended functionalities.
# true

# %%
Read("dot.gd");

# %%
Read("dot.gi");

# %%
S := NumericalSemigroup(4,6,9);
# Out:
# Numerical semigroup with 3 generators

# %%
JupyterSplashDot(DotTreeOfGluingsOfNumericalSemigroup(S, 4));

# %%
betti := HasseDiagramOfBettiElementsOfNumericalSemigroup(S);

# %%
JupyterSplashDot(DotBinaryRelation(betti));

# %%
apery := HasseDiagramOfAperyListOfNumericalSemigroup(S, 20);

# %%
JupyterSplashDot(DotBinaryRelation(apery));

# %%
JupyterSplashDot(DotOverSemigroupsNumericalSemigroup(S));

# %%
l:=DecomposeIntoIrreducibles(NumericalSemigroup(4,6,9,11));
# Out:
# [ Numerical semigroup with 2 generators, Numerical semigroup with 3 generators ]

# %%
List(l,MinimalGenerators);
# Out:
# [ [ 3, 4 ], [ 4, 5, 6 ] ]

# %%
g:=GraphAssociatedToElementInNumericalSemigroup(18,S);
# Out:
# [ [ 4, 6, 9 ], [ [ 4, 6 ] ] ]

# %%
JupyterSplashDot(DotBinaryRelation(BinaryRelationByElements(Domain(g[1]), List(g[2],Tuple))));

# %%
JupyterSplashDot(DotRosalesGraph(18,S));

# %%
f:=FactorizationsElementWRTNumericalSemigroup(30,S);
# Out:
# [ [ 6, 1, 0 ], [ 3, 3, 0 ], [ 0, 5, 0 ], [ 3, 0, 2 ], [ 0, 2, 2 ] ]

# %%
JupyterSplashDot(DotFactorizationGraph(f));

# %%
f:=FactorizationsElementWRTNumericalSemigroup(18,S);
# Out:
# [ [ 3, 1, 0 ], [ 0, 3, 0 ], [ 0, 0, 2 ] ]

# %%
eq:=EquivalenceRelationByPartition(Domain(f), RClassesOfSetOfFactorizations(f));

# %%
JupyterSplashDot(DotBinaryRelation(eq));
